# %% [markdown]
# # Palmarès
#
# Versione interattiva di `scripts/generate_palmares.py`. Legge configurazione e dataset, calcola il palmarès e stampa la tabella senza salvare file.

# %%
from pathlib import Path
import sys

import yaml

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.data_loader import load_results
from src.statistics import build_palmares

# %% [markdown]
# ## Configurazione e dati

# %%
with (PROJECT_ROOT / "configs" / "config.yaml").open(encoding="utf-8") as stream:
    config = yaml.safe_load(stream)

years = config["year_selection"]
results = load_results(
    PROJECT_ROOT / config["data"]["file_path"],
    years["first_year"],
    years["last_year"],
)

print(f"Stagioni caricate: {years['first_year']}/{str(years['first_year'] + 1)[-2:]} - {years['last_year']}/{str(years['last_year'] + 1)[-2:]}")
print(f"Allenatori: {len(results.columns)}")

# %% [markdown]
# ## Classifica all-time

# %%
palmares = build_palmares(results)
print(palmares.to_string(index=False))
